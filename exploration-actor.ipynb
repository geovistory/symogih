# %%
# Python lib
import os
import pandas as pd

# External lib
import plotly.express as px

# Local lib
import toolkit as tk

# Connect to db
tk.db_connect(os.environ.get('YELLOW_BHP'))
# Out:
# >> Connecting to PGSQL Database ... Connected!

# %% [markdown]
# # Get data

# %%
actor = tk.db_execute('select * from bhp.actor')
tk.infos(actor, 2)
# Out:
# Shape:  (61556, 19)
#    pk_actor concat_actr          concat_standard_name  begin_year  \
# 0     44895   Actr44895  Sainte-Marie Perrin, Antoine      1870.0
# 1     47015   Actr47015         Costantino da Carrara      1506.0
#
#   certainty_begin notes_begin  end_year certainty_end notes_end gender_iso  \
# 0               3           3    1930.0             3         3          1
# 1               1           2    1545.0             3         4          1
#
#                                                notes  fk_abob_type_actor  \
# 0  <p>Il s'agit probablement d'Antoine Joseph Sai...               104.0
# 1                                               None               104.0
#
#    creator           creation_time  modifier   modification_time  \
# 0     43.0 2012-04-08 01:11:47.600       2.0 2013-12-18 15:35:49
# 1     30.0 2013-07-26 14:08:34.100      30.0 2013-12-18 15:35:49
#
#                                         concat_names standard_text_property  \
# 0  sainte-marie perrin, antoine Sainte-Marie Perr...                   None
# 1        costantino da carrara Costantino da Carrara                   None
#
#    count_text_property
# 0                    0
# 1                    0

# %% [markdown]
# # Format data

# %%
# Rename columns
actor.rename(columns={
    'concat_standard_name':'name', 
    'begin_year':'birth_year', 
    'certainty_begin':'birth_year_certainty',
    'notes_begin': 'notes_birth',
    'end_year':'death_year', 
    'certainty_end':'death_year_certainty',
    'notes_end': 'notes_death',
    'concat_actr': 'id',
    'gender_iso': 'gender',
    'fk_abob_type_actor': 'fk_type',
    'creator': 'fk_creator',
    'modifier':'fk_modifier'
}, inplace=True, errors='ignore')

# Column format
actor['birth_year'] = actor['birth_year'].astype(pd.Int64Dtype())
actor['birth_year_certainty'] = actor['birth_year_certainty'].astype(pd.Int64Dtype())
actor['notes_birth'] = actor['notes_birth'].astype(pd.Int64Dtype())
actor['death_year'] = actor['death_year'].astype(pd.Int64Dtype())
actor['death_year_certainty'] = actor['death_year_certainty'].replace(' ', pd.NA).astype(pd.Int64Dtype())
actor['notes_death'] = actor['notes_death'].astype(pd.Int64Dtype())
actor['gender'] = actor['gender'].astype(pd.Int64Dtype())
actor['fk_type'] = actor['fk_type'].astype(pd.Int64Dtype())
actor['fk_creator'] = actor['fk_creator'].astype(pd.Int64Dtype())
actor['creation_time'] = pd.to_datetime(actor['creation_time'])
actor['fk_modifier'] = actor['fk_modifier'].astype(pd.Int64Dtype())
actor['modification_time'] = pd.to_datetime(actor['modification_time'])
actor.fillna(pd.NA, inplace=True)

tk.infos(actor, 2)
# Out:
# Shape:  (61556, 19)
#    pk_actor         id                          name  birth_year  \
# 0     44895  Actr44895  Sainte-Marie Perrin, Antoine        1870
# 1     47015  Actr47015         Costantino da Carrara        1506
#
#    birth_year_certainty  notes_birth  death_year  death_year_certainty  \
# 0                     3            3        1930                     3
# 1                     1            2        1545                     3
#
#    notes_death  gender                                              notes  \
# 0            3       1  <p>Il s'agit probablement d'Antoine Joseph Sai...
# 1            4       1                                               <NA>
#
#    fk_type  fk_creator           creation_time  fk_modifier  \
# 0      104          43 2012-04-08 01:11:47.600            2
# 1      104          30 2013-07-26 14:08:34.100           30
#
#     modification_time                                       concat_names  \
# 0 2013-12-18 15:35:49  sainte-marie perrin, antoine Sainte-Marie Perr...
# 1 2013-12-18 15:35:49        costantino da carrara Costantino da Carrara
#
#   standard_text_property  count_text_property
# 0                   <NA>                    0
# 1                   <NA>                    0

# %% [markdown]
# # Enlever tous les acteurs [à identifier]

# %%
actor = actor[~actor['name'].str.contains('\[à identifier\]')].reset_index(drop=True)

tk.infos(actor, 2)
# Out:
# Shape:  (59625, 19)
#    pk_actor         id                          name  birth_year  \
# 0     44895  Actr44895  Sainte-Marie Perrin, Antoine        1870
# 1     47015  Actr47015         Costantino da Carrara        1506
#
#    birth_year_certainty  notes_birth  death_year  death_year_certainty  \
# 0                     3            3        1930                     3
# 1                     1            2        1545                     3
#
#    notes_death  gender                                              notes  \
# 0            3       1  <p>Il s'agit probablement d'Antoine Joseph Sai...
# 1            4       1                                               <NA>
#
#    fk_type  fk_creator           creation_time  fk_modifier  \
# 0      104          43 2012-04-08 01:11:47.600            2
# 1      104          30 2013-07-26 14:08:34.100           30
#
#     modification_time                                       concat_names  \
# 0 2013-12-18 15:35:49  sainte-marie perrin, antoine Sainte-Marie Perr...
# 1 2013-12-18 15:35:49        costantino da carrara Costantino da Carrara
#
#   standard_text_property  count_text_property
# 0                   <NA>                    0
# 1                   <NA>                    0

# %% [markdown]
# # Répartition des types d'acteurs

# %%
tk.histogram(actor, 'fk_type', 'Type distribution')

# %% [markdown]
# ## Détail des acters non 104

# %%
actor[actor['fk_type'] == 106]
# Out:
#        pk_actor         id                          name  birth_year  \
# 10331     59031  Actr59031                Forster, James        1830
# 28906     60660  Actr60660                 Valjean, Jean        1769
# 45842     46914  Actr46914  Dieu (conception chrétienne)        <NA>
#
#        birth_year_certainty  notes_birth  death_year  death_year_certainty  \
# 10331                     3            3        1930                     3
# 28906                     1         <NA>        1833                     1
# 45842                     1         <NA>        <NA>                  <NA>
#
#        notes_death  gender notes  fk_type  fk_creator           creation_time  \
# 10331            3       1  <NA>      106          81 2016-11-29 11:05:00.060
# 28906         <NA>       1  <NA>      106         122 2018-10-23 16:48:50.050
# 45842         <NA>       0  <NA>      106           3 2013-07-04 11:43:15.990
#
#        fk_modifier   modification_time  \
# 10331           81 2016-11-29 11:05:00
# 28906          122 2018-10-23 16:48:50
# 45842            3 2013-12-18 15:24:16
#
#                                             concat_names  \
# 10331                      forster, james Forster, James
# 28906                        valjean, jean Valjean, Jean
# 45842  dieu (conception chretienne) Dieu (conception ...
#
#                                   standard_text_property  count_text_property
# 10331  <p>Personnage de Jules Verne dans Le Tour du m...                    1
# 28906  <p>Personnage de fiction, héros du roman "Les ...                    1
# 45842   <p>La divinité dans les religions chétiennes</p>                    1

# %% [markdown]
# # Analyse des dates de naissances

# %%
px.violin(actor, x='birth_year', color='gender', height=700)

# %% [markdown]
# # Analyse des dates de mort

# %%
px.violin(actor, x='death_year', color='gender', height=700)

# %% [markdown]
# # Contribution des créateurs

# %%
tk.histogram(actor, 'fk_creator', 'Contribution des créateurs', max_number=10)

# %% [markdown]
# # Analyse des dates d'ajout des données

# %%
px.violin(actor, x='creation_time')
