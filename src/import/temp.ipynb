# %%
# %load_ext autoreload
# %autoreload 2

env = 'prod'
pk_project = 6857901
execute = False
metadata_str = ''
import_manner = 'one-shot'

import os
import pandas as pd
import numpy as np
from datetime import datetime
import duckdb
import plotly.express as px

import geovpylib.analysis as a
import geovpylib.database as db
import geovpylib.pks as pks
import geovpylib.recordlinkage as rl
import geovpylib.sparql as sparql
import geovpylib.utils as u
import geovpylib.queries as q

eta = u.Eta()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
db.connect_geovistory(env, skip_protection=True)

graph = q.get_graph([785518], 6857901)
graph
# q.show_graph(graph,'test')
# Out:
# [DB] Requests will not be executed
# [DB] Connecting to PRODUCTION Database ... Connected!
# > Getting graph of 1 entities
#   > Getting graph of 7 entities
#     > Getting graph of 3 entities
#     > Getting graph of 5 entities
#     > Getting graph of 2 entities
#   > Getting graph of 3 entities
#     > Getting graph of 2 entities
#     > Getting graph of 2 entities
#   > Getting graph of 5 entities
#     pk_stmt                                      subject  \
# 0   2077175          Appellation in a Language (2077171)
# 1   2077173          Appellation in a Language (2077171)
# 2   2077174          Appellation in a Language (2077171)
# 3   6141719          Appellation in a Language (6141715)
# 4   6141717          Appellation in a Language (6141715)
# 5   6141718          Appellation in a Language (6141715)
# 6    739345           Appellation in a Language (739342)
# 7    739344           Appellation in a Language (739342)
# 8    739343           Appellation in a Language (739342)
# 9    911228           Appellation in a Language (911224)
# 10   911227           Appellation in a Language (911224)
# 11   911225           Appellation in a Language (911224)
# 12   923140           Appellation in a Language (923136)
# 13   923139           Appellation in a Language (923136)
# 14   923137           Appellation in a Language (923136)
# 15   826118                               Birth (808689)
# 16   812439                               Birth (808689)
# 17  7584664                               Birth (808689)
# 18  7829916                              Death (7726698)
# 19  7804931                              Death (7726698)
# 20  7866636                              Death (7726698)
# 21  2310499                         Definition (2256931)
# 22  2337283                         Definition (2256931)
# 23  7454074                         Definition (7450318)
# 24  7452822                         Definition (7450318)
# 25  1784731                              Gender (739340)
# 26  3229122                              Gender (739340)
# 27  6461769                              Gender (739340)
# 28  7455326                              Person (785518)
# 29  3141308                              Person (785518)
# 30  6464731                              Person (785518)
# 31  6464729                              Person (785518)
# 32  7440040                              Person (785518)
# 33  7440041                              Person (785518)
# 34  7440042                              Person (785518)
# 35  7447976   Person Appellation in a Language (7442632)
# 36  7445304   Person Appellation in a Language (7442632)
# 37  7446640   Person Appellation in a Language (7442632)
# 38  3229121  Uniform Resource Identifier (URI) (3229119)
# 39  6468816  Uniform Resource Identifier (URI) (6447675)
# 40  6471776  Uniform Resource Identifier (URI) (6450635)
# 41  6471778  Uniform Resource Identifier (URI) (6450637)
# 42  7441353  Uniform Resource Identifier (URI) (7437414)
# 43  7441354  Uniform Resource Identifier (URI) (7437415)
# 44  7441355  Uniform Resource Identifier (URI) (7437416)
# 45  7603229  Uniform Resource Identifier (URI) (7547534)
# 46  7814342  Uniform Resource Identifier (URI) (7786138)
#
#                           property  \
# 0   is appellation for language of
# 1                   refers to name
# 2                 used in language
# 3   is appellation for language of
# 4                   refers to name
# 5                 used in language
# 6   is appellation for language of
# 7                   refers to name
# 8                 used in language
# 9   is appellation for language of
# 10                  refers to name
# 11                used in language
# 12  is appellation for language of
# 13                  refers to name
# 14                used in language
# 15             at some time within
# 16               brought into life
# 17        same as URI [owl:sameAs]
# 18             at some time within
# 19        same as URI [owl:sameAs]
# 20                    was death of
# 21                    has language
# 22               has value version
# 23                    has language
# 24               has value version
# 25                  has definition
# 26        same as URI [owl:sameAs]
# 27        same as URI [owl:sameAs]
# 28                  has definition
# 29                      has gender
# 30        same as URI [owl:sameAs]
# 31        same as URI [owl:sameAs]
# 32        same as URI [owl:sameAs]
# 33        same as URI [owl:sameAs]
# 34        same as URI [owl:sameAs]
# 35  is appellation for language of
# 36                  refers to name
# 37                used in language
# 38                       has value
# 39                       has value
# 40                       has value
# 41                       has value
# 42                       has value
# 43                       has value
# 44                       has value
# 45                       has value
# 46                       has value
#
#                                                object
# 0                                     Gender (739340)
# 1                                            Männlich
# 2                                                 deu
# 3                                     Gender (739340)
# 4                                            Masculin
# 5                                                 fra
# 6                                     Gender (739340)
# 7                                            Maschile
# 8                                                 ita
# 9                                     Gender (739340)
# 10                                              Homme
# 11                                                fra
# 12                                    Gender (739340)
# 13                                               Male
# 14                                                eng
# 15                                     (1571, 12, 27)
# 16                                    Person (785518)
# 17        Uniform Resource Identifier (URI) (7547534)
# 18                                       (1630, 1, 1)
# 19        Uniform Resource Identifier (URI) (7786138)
# 20                                    Person (785518)
# 21                                                fra
# 22                           Mâle de l'espèce humaine
# 23                                                deu
# 24  [Complément] Astronom; Mathematiker [Notes] fb...
# 25                               Definition (2256931)
# 26        Uniform Resource Identifier (URI) (3229119)
# 27        Uniform Resource Identifier (URI) (6447675)
# 28                               Definition (7450318)
# 29                                    Gender (739340)
# 30        Uniform Resource Identifier (URI) (6450637)
# 31        Uniform Resource Identifier (URI) (6450635)
# 32        Uniform Resource Identifier (URI) (7437414)
# 33        Uniform Resource Identifier (URI) (7437415)
# 34        Uniform Resource Identifier (URI) (7437416)
# 35                                    Person (785518)
# 36                                   Kepler, Johannes
# 37                                                fra
# 38            http://www.wikidata.org/entity/Q6581097
# 39            http://www.wikidata.org/entity/Q6581097
# 40        http://dbpedia.org/resource/Johannes_Kepler
# 41                     http://d-nb.info/gnd/118561448
# 42                   http://www.idref.fr/026947676/id
# 43                http://symogih.org/resource/Actr195
# 44          http://data.bnf.fr/ark:/12148/cb11909597m
# 45              http://symogih.org/resource/Info29659
# 46              http://symogih.org/resource/Info29660
