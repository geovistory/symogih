# %%
bhp_persons_path = '../../data/persons-bhp.csv'
trigram_score_threshold = 0.9

# %%
import math
import pandas as pd
import duckdb
import geovpylib.utils as u
import geovpylib.analysis as a

eta = u.Eta()

# %% [markdown]
# # BHP'actors persons record linkage

# %% [markdown]
# ## Get data

# %%
persons = u.read_df(bhp_persons_path)
a.set_types(persons, {'birth_year': 'int', 'death_year': 'int', 'certainty_birth': 'int', 'certainty_death': 'int'})
u.infos(persons)
# Out:
# Shape:  (62523, 10)
#         pk                         name first_name            last_name  \
# 0  44895.0  antoine sainte-marie perrin    antoine  sainte-marie perrin
# 1  47015.0                          NaN        NaN                  NaN
# 2  47190.0               alberto duimio    alberto               duimio
# 3  47190.0              albertus divini   albertus               divini
# 4  47578.0                 angelo zampa     angelo                zampa
#
#   gender  birth_year  certainty_birth  death_year  certainty_death dataset
# 0   Male        <NA>                0        <NA>                0     bhp
# 1   Male        1506                1        <NA>                1     bhp
# 2   Male        1510                1        1564                1     bhp
# 3   Male        1510                1        1564                1     bhp
# 4   Male        <NA>                0        1575                0     bhp

# %% [markdown]
# ## Find duplicated

# %%
def find_dupplicated(df, additional_columns, criterion, where=False):
    """According to the given criterion, add the found entities to the dataframe."""

    sql = f"""
        select 
            p1.pk as pk_l,
            p2.pk as pk_r,
            p1.name as name_l,
            p2.name as name_r,
            p1.gender as gender_l,
            p2.gender as gender_r,
            p1.birth_year as birth_year_l,
            p2.birth_year as birth_year_r,
            p1.death_year as death_year_l,
            p2.death_year as death_year_r,
            {additional_columns}
        from persons p1 inner join persons p2 on p1.pk != p2.pk and {criterion}
    """
    if where: sql += f" where {where}"
    # print(sql)

    found = pd.concat([df, duckdb.query(sql).to_df()])
    a.set_types(found, {'pk_l':'int', 'pk_r':'int'})

    # To de duplicate the couples
    found['key'] = [str(min(row['pk_l'], row['pk_r'])) + '-' + str(max(row['pk_l'], row['pk_r'])) for i, row in found.iterrows()]
    found.drop_duplicates(subset=['key'], inplace=True, keep='first')
    found.drop(columns=['key'], inplace=True)
    found.reset_index(drop=True, inplace=True)

    return found

matches = pd.DataFrame()

# %% [markdown]
# ### 0/ Every thing match exactly

# %%
level = 0

matches = find_dupplicated(
    matches,
    f"{level} as level",
    "p1.name = p2.name and p1.gender = p2.gender and p1.birth_year = p2.birth_year and p1.death_year = p2.death_year"
)

u.infos(matches[matches['level'] == level])
# Out:
# Shape:  (22, 11)
#     pk_l   pk_r                       name_l                       name_r  \
# 0  15155  15156                 jean juvenel                 jean juvenel
# 1  20092  20093                     ? delort                     ? delort
# 2   2886  49782                 pietro duodo                 pietro duodo
# 3  13313  22099          jean-jacques dobler          jean-jacques dobler
# 4  51744  51736  francesco roncalli parolino  francesco roncalli parolino
#
#   gender_l gender_r  birth_year_l  birth_year_r  death_year_l  death_year_r  \
# 0     Male     Male          1643          1643          1675          1675
# 1     Male     Male          1641          1641          1641          1641
# 2     Male     Male          1554          1554          1610          1610
# 3     Male     Male          1749          1749          1838          1838
# 4     Male     Male          1692          1692          1763          1763
#
#    level
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %% [markdown]
# ### 1/ Every thing match exactly except the name (levenshtein = 1)

# %%
level = 1

matches = find_dupplicated(
    matches,
    f"{level} as level",
    "p1.gender = p2.gender and p1.birth_year = p2.birth_year and p1.death_year = p2.death_year and levenshtein(p1.name, p2.name) <= 1"
)

u.infos(matches[matches['level'] == level])
# Out:
# Shape:  (15, 11)
#      pk_l   pk_r                              name_l  \
# 22  47825  50830  louis nicolas neuville de villeroy
# 23  50150    820                 guglielmo grataroli
# 24  55242  55277                        felix prudho
# 25  56121  38579             konrad victor schneider
# 26  55266  55250                     william whewell
#
#                                  name_r gender_l gender_r  birth_year_l  \
# 22  louis nicolas neufville de villeroy     Male     Male          1663
# 23                  guglielmo gratarolo     Male     Male          1516
# 24                         felix prudlo     Male     Male          1794
# 25              conrad victor schneider     Male     Male          1614
# 26                     william wheewell     Male     Male          1794
#
#     birth_year_r  death_year_l  death_year_r  level
# 22          1663          1734          1734      1
# 23          1516          1568          1568      1
# 24          1794          1837          1837      1
# 25          1614          1680          1680      1
# 26          1794          1866          1866      1

# %% [markdown]
# ### 2/ Every thing match exactly except the name (levenshtein = 2)

# %%
level = 2

matches = find_dupplicated(
    matches,
    f"{level} as level",
    "p1.gender = p2.gender and p1.birth_year = p2.birth_year and p1.death_year = p2.death_year and levenshtein(p1.name, p2.name) <= 2"
)

u.infos(matches[matches['level'] == level])
# Out:
# Shape:  (7, 11)
#      pk_l   pk_r                    name_l                  name_r gender_l  \
# 37  51896     60          ismael bouilliau          ismal boulliau     Male
# 38  56974  47395  jos fernandez   del toro  jos fernandez del toro     Male
# 39  56975  47396   juan antonio   llorente   juan antonio llorente     Male
# 40  54053  54073    adrien marie le jendre   adrien marie legendre     Male
# 41    243  47426          michele mazarino       michele mazzarini     Male
#
#    gender_r  birth_year_l  birth_year_r  death_year_l  death_year_r  level
# 37     Male          1605          1605          1694          1694      2
# 38     Male          1663          1663          1733          1733      2
# 39     Male          1750          1750          1823          1823      2
# 40     Male          1752          1752          1833          1833      2
# 41     Male          1605          1605          1648          1648      2

# %% [markdown]
# ### 3/ Every thing match exactly except the name (levenshtein = 3). Names with "?" are removed

# %%
level = 3

matches = find_dupplicated(
    matches,
    f"{level} as level",
    "p1.gender = p2.gender and p1.birth_year = p2.birth_year and p1.death_year = p2.death_year and levenshtein(p1.name, p2.name) <= 3",
    f"p1.name not like '?%' and p2.name not like '?%'"
)

u.infos(matches[matches['level'] == level])
# Out:
# Shape:  (10, 11)
#      pk_l   pk_r                      name_l                   name_r  \
# 44  17735  17775                pierre moine             pierre marie
# 45  19984  19987              charles merlan           charles martin
# 46   1514  56122                domingo soto          domingo de soto
# 47  52684    444            hermann boorhave         herman boerhaave
# 48  21816  20961  johann andras de scheidlin  johann andras scheidlin
#
#    gender_l gender_r  birth_year_l  birth_year_r  death_year_l  death_year_r  \
# 44     Male     Male          1632          1632          1632          1632
# 45     Male     Male          1635          1635          1636          1636
# 46     Male     Male          1494          1494          1560          1560
# 47     Male     Male          1668          1668          1738          1738
# 48     Male     Male          1734          1734          1756          1756
#
#     level
# 44      3
# 45      3
# 46      3
# 47      3
# 48      3

# %% [markdown]
# ### 4/ Birth dates and names match exactly

# %%
level = 4

matches = find_dupplicated(
    matches,
    f"{level} as level",
    "p1.birth_year = p2.birth_year and levenshtein(p1.name, p2.name) <= 0",
)

u.infos(matches[matches['level'] == level])
# Out:
# Shape:  (93, 11)
#      pk_l   pk_r                    name_l                    name_r gender_l  \
# 54  15062  18728  jean jacques huguedobler  jean jacques huguedobler     Male
# 55  14695  14700        jean rodolphe frey        jean rodolphe frey     Male
# 56  14021  14022               gdon brutel               gdon brutel     Male
# 57  14023  14024            jacques brutel            jacques brutel     Male
# 58  14915  17320           jean grevoullet           jean grevoullet     Male
#
#    gender_r  birth_year_l  birth_year_r  death_year_l  death_year_r  level
# 54     Male          1660          1660           NaN           NaN      4
# 55     Male          1662          1662           NaN           NaN      4
# 56     Male          1665          1665        1668.0           NaN      4
# 57     Male          1666          1666           NaN           NaN      4
# 58     Male          1633          1633        1681.0           NaN      4

# %% [markdown]
# ### 5/ Birth dates match exactly, names: levenshtein = 1

# %%
level = 5

matches = find_dupplicated(
    matches,
    f"{level} as level",
    "p1.birth_year = p2.birth_year and levenshtein(p1.name, p2.name) <= 1",
)

u.infos(matches[matches['level'] == level])
# Out:
# Shape:  (31, 11)
#       pk_l   pk_r            name_l            name_r gender_l gender_r  \
# 147  13828  15045    susanne berard    susanne beraud   Female   Female
# 148  13850  14052     marie bernaud      marie beraud   Female   Female
# 149  15417  15420     pierre maille    pierre maillet     Male     Male
# 150   8601   6477    joseph jaillet    joseph paillet     Male     Male
# 151  13760  13852  franoise barnaud  franoise bernaud   Female   Female
#
#      birth_year_l  birth_year_r  death_year_l  death_year_r  level
# 147          1671          1671           NaN           NaN      5
# 148          1646          1646           NaN           NaN      5
# 149          1680          1680           NaN           NaN      5
# 150          1884          1884           NaN           NaN      5
# 151          1680          1680           NaN        1681.0      5

# %% [markdown]
# ### 6/ Birth dates match at +/- 1 years, names match exactly

# %%
level = 6

matches = find_dupplicated(
    matches,
    f"{level} as level",
    "p1.birth_year - 1 <= p2.birth_year and p2.birth_year <= p1.birth_year + 1 and levenshtein(p1.name, p2.name) <= 0",
)

u.infos(matches[matches['level'] == level])
# Out:
# Shape:  (64, 11)
#       pk_l   pk_r               name_l               name_r gender_l gender_r  \
# 178  38975   5518        paul gauthier        paul gauthier     Male     Male
# 179  10679  11026          jean martin          jean martin     Male     Male
# 180   9957   9413         louis gindre         louis gindre     Male     Male
# 181   4899  56126  alphonse dupasquier  alphonse dupasquier     Male     Male
# 182   4545  22495  paul flix brolemann  paul flix brolemann     Male     Male
#
#      birth_year_l  birth_year_r  death_year_l  death_year_r  level
# 178          1894          1893        1937.0           NaN      6
# 179          1884          1883           NaN           NaN      6
# 180          1868          1867        1949.0        1902.0      6
# 181          1794          1793           NaN        1848.0      6
# 182          1784          1783        1858.0           NaN      6

# %% [markdown]
# ### 7/ Birth dates match at +/- 1 years, names: levenshtein = 1

# %%
level = 7

matches = find_dupplicated(
    matches,
    f"{level} as level",
    "p1.birth_year - 1 <= p2.birth_year and p2.birth_year <= p1.birth_year + 1 and levenshtein(p1.name, p2.name) <= 1",
)

u.infos(matches[matches['level'] == level])
# Out:
# Shape:  (28, 11)
#       pk_l   pk_r            name_l           name_r gender_l gender_r  \
# 242   9438   5485     marcel rodier    marcel rozier     Male     Male
# 243  57937   7438     maurice dlage   maurice delage     Male     Male
# 244   6768  32343    marcel mounier   marcel meunier     Male     Male
# 245  10676   8885      henry martin     henri martin     Male     Male
# 246  45660  45654  germaine hangest  germain hangest   Female     Male
#
#      birth_year_l  birth_year_r  death_year_l  death_year_r  level
# 242          1915          1914           NaN           NaN      7
# 243          1907          1906        1931.0           NaN      7
# 244          1894          1893           NaN        1971.0      7
# 245          1893          1892           NaN           NaN      7
# 246          1884          1883        1986.0        1963.0      7

# %% [markdown]
# ### 8/ Birth dates match at +/- 2 years, names: levenshtein = 0

# %%
level = 8

matches = find_dupplicated(
    matches,
    f"{level} as level",
    "p1.birth_year - 2 <= p2.birth_year and p2.birth_year <= p1.birth_year + 2 and levenshtein(p1.name, p2.name) <= 0",
)

u.infos(matches[matches['level'] == level])
# Out:
# Shape:  (91, 11)
#       pk_l   pk_r          name_l          name_r gender_l gender_r  \
# 270   7527  21939     henri faure     henri faure     Male     Male
# 271  21939   8369     henri faure     henri faure     Male     Male
# 272   6924   6972   georges blanc   georges blanc     Male     Male
# 273   8102   9448   yvonne cottin   yvonne cottin   Female   Female
# 274   7421   9095  pierre reynaud  pierre reynaud     Male     Male
#
#      birth_year_l  birth_year_r  death_year_l  death_year_r  level
# 270          1905          1903           NaN           NaN      8
# 271          1903          1901           NaN           NaN      8
# 272          1902          1900           NaN           NaN      8
# 273          1899          1897           NaN           NaN      8
# 274          1879          1877           NaN           NaN      8

# %% [markdown]
# ### 9/ Birth dates match at +/- 2 years, names: levenshtein = 1

# %%
level = 9

matches = find_dupplicated(
    matches,
    f"{level} as level",
    "p1.birth_year - 2 <= p2.birth_year and p2.birth_year <= p1.birth_year + 2 and levenshtein(p1.name, p2.name) <= 1",
)

u.infos(matches[matches['level'] == level])
# Out:
# Shape:  (29, 11)
#       pk_l   pk_r            name_l           name_r gender_l gender_r  \
# 361  10026  32065    philippe cotte   philippe coste     Male     Male
# 362   9250  10639        paul delay      paul delaye     Male     Male
# 363  21932  62540         ren demay        ren debay     Male     Male
# 364   9593   6250  charles gauthier  charles gautier     Male     Male
# 365  61835  38761        paul auban       paul alban     Male     Male
#
#      birth_year_l  birth_year_r  death_year_l  death_year_r  level
# 361          1906          1904           NaN        1974.0      9
# 362          1885          1883           NaN           NaN      9
# 363          1880          1878        1963.0           NaN      9
# 364          1876          1874           NaN           NaN      9
# 365          1869          1867        1945.0        1936.0      9

# %% [markdown]
# ## Save

# %%
u.infos(matches)
u.save_df(matches, '../../data/record-linkage_bhp-tradi.csv')
# Out:
# Shape:  (390, 11)
#     pk_l   pk_r                       name_l                       name_r  \
# 0  15155  15156                 jean juvenel                 jean juvenel
# 1  20092  20093                     ? delort                     ? delort
# 2   2886  49782                 pietro duodo                 pietro duodo
# 3  13313  22099          jean-jacques dobler          jean-jacques dobler
# 4  51744  51736  francesco roncalli parolino  francesco roncalli parolino
#
#   gender_l gender_r  birth_year_l  birth_year_r  death_year_l  death_year_r  \
# 0     Male     Male          1643          1643        1675.0        1675.0
# 1     Male     Male          1641          1641        1641.0        1641.0
# 2     Male     Male          1554          1554        1610.0        1610.0
# 3     Male     Male          1749          1749        1838.0        1838.0
# 4     Male     Male          1692          1692        1763.0        1763.0
#
#    level
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
