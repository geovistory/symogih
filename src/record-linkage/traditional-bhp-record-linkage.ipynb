# %%
bhp_persons_path = '../../data/persons-bhp.csv'
trigram_score_threshold = 0.9

# %%
import math
import pandas as pd
import duckdb
import geovpylib.utils as u
import geovpylib.analysis as a

eta = u.Eta()

# %% [markdown]
# # BHP'actors persons record linkage

# %% [markdown]
# ## Get data

# %%
persons = u.read_df(bhp_persons_path)
a.set_types(persons, {'birth_year': 'int', 'death_year': 'int', 'certainty_birth': 'int', 'certainty_death': 'int'})
u.infos(persons)
# Out:
# Shape:  (62527, 10)
#         pk                         name first_name            last_name  \
# 0  44895.0  antoine sainte-marie perrin    antoine  sainte-marie perrin
# 1  47015.0                          NaN        NaN                  NaN
# 2  47190.0               alberto duimio    alberto               duimio
# 3  47190.0              albertus divini   albertus               divini
# 4  47578.0                 angelo zampa     angelo                zampa
#
#   gender  birth_year  certainty_birth  death_year  certainty_death dataset
# 0   Male        1870                3        1930                3     bhp
# 1   Male        1506                1        1545                1     bhp
# 2   Male        1510                1        1564                1     bhp
# 3   Male        1510                1        1564                1     bhp
# 4   Male        <NA>                0        1575                0     bhp

# %% [markdown]
# ## Find duplicated

# %%
def find_dupplicated(df, additional_columns, criterion):
    """According to the given criterion, add the found entities to the dataframe."""

    found = pd.concat([df, duckdb.query(f"""
        select 
            p1.pk as pk_l,
            p2.pk as pk_r,
            p1.name as name_l,
            p2.name as name_r,
            p1.gender as gender_l,
            p2.gender as gender_r,
            p1.birth_year as birth_year_l,
            p2.birth_year as birth_year_r,
            p1.death_year as death_year_l,
            p2.death_year as death_year_r,
            {additional_columns}
        from persons p1 inner join persons p2 on p1.pk != p2.pk and {criterion}
    """).to_df()
    ])

    a.set_types(found, {'pk_l':'int', 'pk_r':'int'})

    # To de duplicate the couples
    found['key'] = [str(min(row['pk_l'], row['pk_r'])) + '-' + str(max(row['pk_l'], row['pk_r'])) for i, row in found.iterrows()]
    found.drop_duplicates(subset=['key'], inplace=True, keep='first')
    found.drop(columns=['key'], inplace=True)
    found.reset_index(drop=True, inplace=True)

    return found

# %% [markdown]
# ### 1/ Gender, birth year, death year matches exactly

# %% [markdown]
# #### Name Levenshtein distance = 0

# %%
matches = find_dupplicated(
    pd.DataFrame(), 
    "1 as level, 0 as levenshtein", 
    "p1.name = p2.name and p1.gender = p2.gender and p1.birth_year = p2.birth_year and p1.death_year = p2.death_year"
)

u.infos(matches[(matches['level'] == 1) & (matches['levenshtein'] == 0)])
# Out:
# Shape:  (27, 12)
#     pk_l   pk_r                       name_l                       name_r  \
# 0  15155  15156                 jean juvenel                 jean juvenel
# 1  20092  20093                     ? delort                     ? delort
# 2   2886  49782                 pietro duodo                 pietro duodo
# 3  13313  22099          jean-jacques dobler          jean-jacques dobler
# 4  51744  51736  francesco roncalli parolino  francesco roncalli parolino
#
#   gender_l gender_r  birth_year_l  birth_year_r  death_year_l  death_year_r  \
# 0     Male     Male          1643          1643          1675          1675
# 1     Male     Male          1641          1641          1641          1641
# 2     Male     Male          1554          1554          1610          1610
# 3     Male     Male          1749          1749          1838          1838
# 4     Male     Male          1692          1692          1763          1763
#
#    level  levenshtein
# 0      1            0
# 1      1            0
# 2      1            0
# 3      1            0
# 4      1            0

# %% [markdown]
# #### Name Levenshtein distance = 1

# %%
matches = find_dupplicated(
    matches, 
    "1 as level, 1 as levenshtein", 
    "p1.gender = p2.gender and p1.birth_year = p2.birth_year and p1.death_year = p2.death_year and levenshtein(p1.name, p2.name) <= 1"
)

u.infos(matches[(matches['level'] == 1) & (matches['levenshtein'] == 1)])
# Out:
# Shape:  (24, 12)
#      pk_l   pk_r                              name_l  \
# 27  47825  50830  louis nicolas neuville de villeroy
# 28   1452  57598                  jean-paul la roque
# 29  50150    820                 guglielmo grataroli
# 30  55242  55277                        felix prudho
# 31  56121  38579             konrad victor schneider
#
#                                  name_r gender_l gender_r  birth_year_l  \
# 27  louis nicolas neufville de villeroy     Male     Male          1663
# 28                  jean-paul  la roque     Male     Male          1630
# 29                  guglielmo gratarolo     Male     Male          1516
# 30                         felix prudlo     Male     Male          1794
# 31              conrad victor schneider     Male     Male          1614
#
#     birth_year_r  death_year_l  death_year_r  level  levenshtein
# 27          1663          1734          1734      1            1
# 28          1630          1691          1691      1            1
# 29          1516          1568          1568      1            1
# 30          1794          1837          1837      1            1
# 31          1614          1680          1680      1            1

# %% [markdown]
# #### Name Levenshtein distance = 2

# %%
matches = find_dupplicated(
    matches, 
    "1 as level, 2 as levenshtein", 
    "p1.gender = p2.gender and p1.birth_year = p2.birth_year and p1.death_year = p2.death_year and levenshtein(p1.name, p2.name) <= 2"
)

u.infos(matches[(matches['level'] == 1) & (matches['levenshtein'] == 2)])
# Out:
# Shape:  (24, 12)
#      pk_l   pk_r                    name_l                  name_r gender_l  \
# 51  51896     60          ismael bouilliau          ismal boulliau     Male
# 52    243  47426          michele mazarino       michele mazzarini     Male
# 53  54053  54073    adrien marie le jendre   adrien marie legendre     Male
# 54  56974  47395  jos fernandez   del toro  jos fernandez del toro     Male
# 55  56975  47396   juan antonio   llorente   juan antonio llorente     Male
#
#    gender_r  birth_year_l  birth_year_r  death_year_l  death_year_r  level  \
# 51     Male          1605          1605          1694          1694      1
# 52     Male          1605          1605          1648          1648      1
# 53     Male          1752          1752          1833          1833      1
# 54     Male          1663          1663          1733          1733      1
# 55     Male          1750          1750          1823          1823      1
#
#     levenshtein
# 51            2
# 52            2
# 53            2
# 54            2
# 55            2

# %% [markdown]
# #### Name Levenshtein distance = 3

# %%
matches = find_dupplicated(
    matches, 
    "1 as level, 3 as levenshtein", 
    "p1.gender = p2.gender and p1.birth_year = p2.birth_year and p1.death_year = p2.death_year and levenshtein(p1.name, p2.name) <= 3"
)

u.infos(matches[(matches['level'] == 1) & (matches['levenshtein'] == 3)])
# Out:
# Shape:  (70, 12)
#      pk_l   pk_r          name_l          name_r gender_l gender_r  \
# 75  16776  17231         ? socin         ? kocha     Male     Male
# 76  17735  17775    pierre moine    pierre marie     Male     Male
# 77  19984  19987  charles merlan  charles martin     Male     Male
# 78  20023  20044         ? pelas        ? meilan     Male     Male
# 79  19985  19989       ? blachon      ? perachon     Male     Male
#
#     birth_year_l  birth_year_r  death_year_l  death_year_r  level  levenshtein
# 75          1718          1718          1718          1718      1            3
# 76          1632          1632          1632          1632      1            3
# 77          1635          1635          1636          1636      1            3
# 78          1638          1638          1638          1638      1            3
# 79          1636          1636          1636          1636      1            3

# %% [markdown]
# ### 2/ Gender, birth year matches exactly

# %% [markdown]
# #### Name Levenshtein distance = 0

# %%
matches = find_dupplicated(
    matches, 
    "2 as level, 0 as levenshtein", 
    "p1.gender = p2.gender and p1.birth_year = p2.birth_year and levenshtein(p1.name, p2.name) <= 0"
)

u.infos(matches[(matches['level'] == 2) & (matches['levenshtein'] == 0)])
# Out:
# Shape:  (111, 12)
#       pk_l   pk_r              name_l              name_r gender_l gender_r  \
# 145  14325  14326   susanne crommelin   susanne crommelin   Female   Female
# 146  14695  14700  jean rodolphe frey  jean rodolphe frey     Male     Male
# 147  14023  14024      jacques brutel      jacques brutel     Male     Male
# 148  14056  14057         isaac burel         isaac burel     Male     Male
# 149  14021  14022         gdon brutel         gdon brutel     Male     Male
#
#      birth_year_l  birth_year_r  death_year_l  death_year_r  level  \
# 145          1676          1676           NaN        1676.0      2
# 146          1662          1662           NaN           NaN      2
# 147          1666          1666           NaN           NaN      2
# 148          1671          1671        1677.0           NaN      2
# 149          1665          1665        1668.0           NaN      2
#
#      levenshtein
# 145            0
# 146            0
# 147            0
# 148            0
# 149            0

# %% [markdown]
# #### Name Levenshtein distance = 1

# %%
matches = find_dupplicated(
    matches, 
    "2 as level, 1 as levenshtein", 
    "p1.gender = p2.gender and p1.birth_year = p2.birth_year and levenshtein(p1.name, p2.name) <= 1"
)

u.infos(matches[(matches['level'] == 2) & (matches['levenshtein'] == 1)])
# Out:
# Shape:  (80, 12)
#       pk_l   pk_r            name_l            name_r gender_l gender_r  \
# 256  13850  14052     marie bernaud      marie beraud   Female   Female
# 257  13828  15045    susanne berard    susanne beraud   Female   Female
# 258  13760  13852  franoise barnaud  franoise bernaud   Female   Female
# 259   8601   6477    joseph jaillet    joseph paillet     Male     Male
# 260  15417  15420     pierre maille    pierre maillet     Male     Male
#
#      birth_year_l  birth_year_r  death_year_l  death_year_r  level  \
# 256          1646          1646           NaN           NaN      2
# 257          1671          1671           NaN           NaN      2
# 258          1680          1680           NaN        1681.0      2
# 259          1884          1884           NaN           NaN      2
# 260          1680          1680           NaN           NaN      2
#
#      levenshtein
# 256            1
# 257            1
# 258            1
# 259            1
# 260            1

# %% [markdown]
# #### Name Levenshtein distance = 2

# %%
matches = find_dupplicated(
    matches, 
    "2 as level, 2 as levenshtein", 
    "p1.gender = p2.gender and p1.birth_year = p2.birth_year and levenshtein(p1.name, p2.name) <= 2"
)

u.infos(matches[(matches['level'] == 2) & (matches['levenshtein'] == 2)])
# Out:
# Shape:  (244, 12)
#       pk_l   pk_r             name_l             name_r gender_l gender_r  \
# 336  13978  57934  salomon breuiller  salomon brevillet     Male     Male
# 337  25200  24595    camille garassu   camille garasson   Female   Female
# 338  25202  24754          adle thom        adle thomet   Female   Female
# 339  13766  49828        marie baron       marie bathon   Female   Female
# 340  15046  30848         marie hoxe          marie roe   Female   Female
#
#      birth_year_l  birth_year_r  death_year_l  death_year_r  level  \
# 336          1647          1647           NaN           NaN      2
# 337          1839          1839           NaN           NaN      2
# 338          1820          1820           NaN           NaN      2
# 339          1645          1645           NaN           NaN      2
# 340          1634          1634        1672.0        1681.0      2
#
#      levenshtein
# 336            2
# 337            2
# 338            2
# 339            2
# 340            2

# %% [markdown]
# ### 3/ Birth year matches exactly

# %% [markdown]
# #### Name Levenshtein distance = 0

# %%
matches = find_dupplicated(
    matches, 
    "3 as level, 0 as levenshtein", 
    "p1.birth_year = p2.birth_year and levenshtein(p1.name, p2.name) <= 0"
)

u.infos(matches[(matches['level'] == 3) & (matches['levenshtein'] == 0)])
# Out:
# Shape:  (25, 12)
#       pk_l   pk_r         name_l         name_r gender_l gender_r  \
# 580  14731  14732       ? gainon       ? gainon     Male   Female
# 581  16729  16730    ? rimmacher    ? rimmacher     Male   Female
# 582  16760  16761        ? croom        ? croom     Male   Female
# 583  15992  15993       ? renaud       ? renaud   Female     Male
# 584  29003  29002  paul fleurieu  paul fleurieu   Female     Male
#
#      birth_year_l  birth_year_r  death_year_l  death_year_r  level  \
# 580          1676          1676        1676.0           NaN      3
# 581          1707          1707           NaN        1707.0      3
# 582          1715          1715           NaN        1715.0      3
# 583          1661          1661           NaN        1678.0      3
# 584          1860          1860           NaN           NaN      3
#
#      levenshtein
# 580            0
# 581            0
# 582            0
# 583            0
# 584            0

# %% [markdown]
# #### Name Levenshtein distance = 1

# %%
matches = find_dupplicated(
    matches, 
    "3 as level, 1 as levenshtein", 
    "p1.birth_year = p2.birth_year and levenshtein(p1.name, p2.name) <= 1"
)

u.infos(matches[(matches['level'] == 3) & (matches['levenshtein'] == 1)])
# Out:
# Shape:  (8, 12)
#       pk_l   pk_r                 name_l                  name_r gender_l  \
# 605  18539  18540             louis moze             louise moze     Male
# 606    137  43258        pierre dumoulin        pierre du moulin      NaN
# 607   1262  45691  louis la rochefoucaud  louis la rochefoucauld      NaN
# 608  25232  25233           emilie clerc             emile clerc   Female
# 609  51302   1162         franois citoys          franois citois     Male
#
#     gender_r  birth_year_l  birth_year_r  death_year_l  death_year_r  level  \
# 605   Female          1655          1655           NaN           NaN      3
# 606     Male          1568          1568        1658.0        1658.0      3
# 607     Male          1615          1615        1654.0        1654.0      3
# 608     Male          1837          1837           NaN           NaN      3
# 609      NaN          1572          1572        1652.0        1652.0      3
#
#      levenshtein
# 605            1
# 606            1
# 607            1
# 608            1
# 609            1

# %% [markdown]
# #### Name Levenshtein distance = 2

# %%
matches = find_dupplicated(
    matches, 
    "3 as level, 2 as levenshtein", 
    "p1.birth_year = p2.birth_year and levenshtein(p1.name, p2.name) <= 2"
)

u.infos(matches[(matches['level'] == 3) & (matches['levenshtein'] == 2)])
# Out:
# Shape:  (40, 12)
#       pk_l   pk_r             name_l             name_r gender_l gender_r  \
# 613  14014  14054           ? brutel            ? burel     Male   Female
# 614  17075  17117  louise larsailler  louise lansuiller   Female     Male
# 615  17199  17201     anne josserand     andr josserand   Female     Male
# 616  16631  16668       anne mallein       andr mallein   Female     Male
# 617  16637  16654        jean dufour      jeanne dufour     Male   Female
#
#      birth_year_l  birth_year_r  death_year_l  death_year_r  level  \
# 613          1675          1675        1675.0        1675.0      3
# 614          1667          1667           NaN           NaN      3
# 615          1642          1642           NaN        1670.0      3
# 616          1684          1684           NaN        1684.0      3
# 617          1684          1684           NaN           NaN      3
#
#      levenshtein
# 613            2
# 614            2
# 615            2
# 616            2
# 617            2

# %% [markdown]
# ### 4/ Death year matches exactly

# %% [markdown]
# #### Name Levenshtein distance = 0

# %%
matches = find_dupplicated(
    matches, 
    "4 as level, 0 as levenshtein", 
    "p1.death_year = p2.death_year and levenshtein(p1.name, p2.name) <= 0"
)

u.infos(matches[(matches['level'] == 4) & (matches['levenshtein'] == 0)])
# Out:
# Shape:  (39, 12)
#       pk_l   pk_r             name_l             name_r gender_l gender_r  \
# 653  14868  43626        jacques got        jacques got     Male     Male
# 654  14458  18517         paul delor         paul delor     Male     Male
# 655  14218  14219            no clot            no clot     Male     Male
# 656  43774  43771    marcus antonius    marcus antonius     Male     Male
# 657  16707  21835  guillaume metzger  guillaume metzger     Male     Male
#
#      birth_year_l  birth_year_r  death_year_l  death_year_r  level  \
# 653        1672.0        1618.0        1679.0        1679.0      4
# 654        1602.0        1655.0        1658.0        1658.0      4
# 655        1634.0        1668.0        1670.0        1670.0      4
# 656         192.0         158.0         238.0         238.0      4
# 657        1700.0           NaN        1700.0        1700.0      4
#
#      levenshtein
# 653            0
# 654            0
# 655            0
# 656            0
# 657            0

# %% [markdown]
# #### Name Levenshtein distance = 1

# %%
matches = find_dupplicated(
    matches, 
    "4 as level, 1 as levenshtein", 
    "p1.death_year = p2.death_year and levenshtein(p1.name, p2.name) <= 1"
)

u.infos(matches[(matches['level'] == 4) & (matches['levenshtein'] == 1)])
# Out:
# Shape:  (34, 12)
#       pk_l   pk_r                  name_l                  name_r gender_l  \
# 692  16748  21840  jean albert finguerlin   jean albert fingerlin     Male
# 693  17998  18555          thodore keller         theodore keller     Male
# 694  19229   1273          jacques aubert          jacques jubert     Male
# 695  60448  60554   louis gabriel oescher  louis gabriel oeschger     Male
# 696  52272  52450             johann wolf            johann wolff     Male
#
#     gender_r  birth_year_l  birth_year_r  death_year_l  death_year_r  level  \
# 692     Male        1706.0           NaN        1712.0        1712.0      4
# 693     Male        1612.0        1656.0        1657.0        1657.0      4
# 694      NaN        1573.0           NaN        1655.0        1655.0      4
# 695     Male        1820.0        1819.0        1887.0        1887.0      4
# 696     Male        1537.0        1577.0        1616.0        1616.0      4
#
#      levenshtein
# 692            1
# 693            1
# 694            1
# 695            1
# 696            1

# %% [markdown]
# ## Save

# %%
u.save_df(matches, '../../data/bhp_entity_recognition.csv')
