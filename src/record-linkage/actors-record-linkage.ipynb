# %%
import pandas as pd

import toolkit as tk

from splink.duckdb.duckdb_linker import DuckDBLinker
from splink.duckdb.duckdb_comparison_library import (
    exact_match,
    levenshtein_at_thresholds,
    
)

# %% [markdown]
# # Persons Record linkage

# %% [markdown]
# ### Get data

# %%
persons = pd.read_csv('../../data/persons-bhp-geov.csv', sep=';')
tk.set_types(persons, {'name':'string', 'gender':'string', 'birth_year':'int', 'death_year':'int'})
persons['unique_id'] = persons['dataset'] + persons['unique_id'].astype(str)
tk.infos(persons)
# Out:
# Shape:  (210172, 7)
#   unique_id     id                         name gender  birth_year  \
# 0      bhp0  44895  antoine sainte-marie perrin   Male        1870
# 1      bhp1  47015                         <NA>   Male        1506
# 2      bhp2  47190               alberto duimio   Male        1510
# 3      bhp3  47190              albertus divini   Male        1510
# 4      bhp4  47578                 angelo zampa   Male        <NA>
#
#    death_year dataset
# 0        1930     bhp
# 1        1545     bhp
# 2        1564     bhp
# 3        1564     bhp
# 4        1575     bhp

# %% [markdown]
# ### Settings & Verifications

# %%
persons_sample = persons#.sample(150000, random_state=42)

br1 = 'l.name = r.name and l.birth_year = r.birth_year'
br2 = 'l.name = r.name and l.death_year = r.death_year'
br3 = 'l.birth_year = r.birth_year and l.death_year = r.death_year and l.gender = r.gender'

settings = {
    "link_type": "dedupe_only",
    "blocking_rules_to_generate_predictions": [br1, br2, br3],
    "comparisons": [
        levenshtein_at_thresholds("name", 1),
        exact_match("gender"),
        exact_match("birth_year"),
        exact_match("death_year"),
    ],
}

# linker = DuckDBLinker(persons_sample, settings)
linker = DuckDBLinker(persons_sample, settings)

linker.cumulative_num_comparisons_from_blocking_rules_chart()
# Out:
# <div id="altair-viz-83aabd81f60747ebaf56e732487cea6d"></div>
# <script type="text/javascript">
#   var VEGA_DEBUG = (typeof VEGA_DEBUG == "undefined") ? {} : VEGA_DEBUG;
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-83aabd81f60747ebaf56e732487cea6d") {
#       outputDiv = document.getElementById("altair-viz-83aabd81f60747ebaf56e732487cea6d");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.17.0?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function maybeLoadScript(lib, version) {
#       var key = `${lib.replace("-", "")}_version`;
#       return (VEGA_DEBUG[key] == version) ?
#         Promise.resolve(paths[lib]) :
#         new Promise(function(resolve, reject) {
#           var s = document.createElement('script');
#           document.getElementsByTagName("head")[0].appendChild(s);
#           s.async = true;
#           s.onload = () => {
#             VEGA_DEBUG[key] = version;
#             return resolve(paths[lib]);
#           };
#           s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#           s.src = paths[lib];
#         });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else {
#       maybeLoadScript("vega", "5")
#         .then(() => maybeLoadScript("vega-lite", "4.17.0"))
#         .then(() => maybeLoadScript("vega-embed", "6"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"$schema": "https://vega.github.io/schema/vega-lite/v5.json", "width": 450, "height": {"step": 20}, "title": {"text": "Count of Additional Comparisons Generated by Each Blocking Rule", "subtitle": "(Counts exclude comparisons already generated by previous rules)"}, "data": {"values": [{"row_count": 128403, "rule": "l.name = r.name and l.birth_year = r.birth_year", "cumulative_rows": 128403, "cartesian": 22086029706, "reduction_ratio": "The rolling reduction ratio with your given blocking rule(s) is 0.999994. This represents the reduction in the total number of comparisons due to your rule(s).", "start": 0}, {"row_count": 81, "rule": "l.name = r.name and l.death_year = r.death_year", "cumulative_rows": 128484, "cartesian": 22086029706, "reduction_ratio": "The rolling reduction ratio with your given blocking rule(s) is 0.999994. This represents the reduction in the total number of comparisons due to your rule(s).", "start": 128403}, {"row_count": 565999, "rule": "l.birth_year = r.birth_year and l.death_year = r.death_year and l.gender = r.gender", "cumulative_rows": 694483, "cartesian": 22086029706, "reduction_ratio": "The rolling reduction ratio with your given blocking rule(s) is 0.999969. This represents the reduction in the total number of comparisons due to your rule(s).", "start": 128484}]}, "mark": "bar", "encoding": {"x": {"title": "Comparisons Generated by Rule(s)", "field": "start", "type": "quantitative"}, "x2": {"field": "cumulative_rows"}, "y": {"field": "rule", "title": "SQL Blocking Rule", "sort": ["-x2"]}, "color": {"field": "rule", "legend": null, "scale": {"scheme": "category20c"}}, "order": {"field": "cumulative_rows"}, "tooltip": [{"type": "nominal", "field": "rule", "title": "SQL Condition"}, {"type": "quantitative", "field": "row_count", "title": "Comparisons Generated", "format": ","}, {"type": "quantitative", "field": "cumulative_rows", "title": "Cumulative Comparisons", "format": ","}, {"type": "quantitative", "field": "cartesian", "title": "Cartesian Product of Input Data", "format": ","}, {"type": "nominal", "field": "reduction_ratio", "title": "Reduction Ratio (cumulative rows/cartesian product)"}]}}, {"mode": "vega-lite"});
# </script>

# %% [markdown]
# ### Training

# %%
blocking_rule_for_training = br1 #"l.name = r.name and l.birth_year = r.birth_year"
linker.estimate_parameters_using_expectation_maximisation(blocking_rule_for_training)

blocking_rule_for_training = br2 #"l.name = r.name and l.death_year = r.death_year"
linker.estimate_parameters_using_expectation_maximisation(blocking_rule_for_training)

blocking_rule_for_training = br3 #"l.birth_year = r.birth_year"
linker.estimate_parameters_using_expectation_maximisation(blocking_rule_for_training)

linker.estimate_u_using_random_sampling(target_rows=1e6)
# Out:
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# l.name = r.name and l.birth_year = r.birth_year
#
# Parameter estimates will be made for the following comparison(s):
#     - gender
#     - death_year
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - name
#     - birth_year
#
# Iteration 1: Largest change in params was 0.176 in the m_probability of death_year, level `Exact match`
# Iteration 2: Largest change in params was 0.00251 in probability_two_random_records_match
# Iteration 3: Largest change in params was 0.00412 in probability_two_random_records_match
# Iteration 4: Largest change in params was 0.00669 in probability_two_random_records_match
# Iteration 5: Largest change in params was 0.0107 in probability_two_random_records_match
# Iteration 6: Largest change in params was 0.017 in probability_two_random_records_match
# Iteration 7: Largest change in params was 0.0263 in probability_two_random_records_match
# Iteration 8: Largest change in params was 0.0398 in probability_two_random_records_match
# Iteration 9: Largest change in params was 0.0578 in probability_two_random_records_match
# Iteration 10: Largest change in params was 0.0793 in probability_two_random_records_match
# Iteration 11: Largest change in params was 0.101 in probability_two_random_records_match
# Iteration 12: Largest change in params was 0.116 in probability_two_random_records_match
# Iteration 13: Largest change in params was 0.119 in probability_two_random_records_match
# Iteration 14: Largest change in params was 0.109 in probability_two_random_records_match
# Iteration 15: Largest change in params was 0.0905 in probability_two_random_records_match
# Iteration 16: Largest change in params was 0.0687 in probability_two_random_records_match
# Iteration 17: Largest change in params was 0.0488 in probability_two_random_records_match
# Iteration 18: Largest change in params was 0.0331 in probability_two_random_records_match
# Iteration 19: Largest change in params was 0.0217 in probability_two_random_records_match
# Iteration 20: Largest change in params was 0.014 in probability_two_random_records_match
# Iteration 21: Largest change in params was 0.00885 in probability_two_random_records_match
# Iteration 22: Largest change in params was 0.00556 in probability_two_random_records_match
# Iteration 23: Largest change in params was 0.00347 in probability_two_random_records_match
# Iteration 24: Largest change in params was 0.00216 in probability_two_random_records_match
# Iteration 25: Largest change in params was 0.00134 in probability_two_random_records_match
#
# EM converged after 25 iterations
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values
#
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# l.name = r.name and l.death_year = r.death_year
#
# Parameter estimates will be made for the following comparison(s):
#     - gender
#     - birth_year
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - name
#     - death_year
#
# Iteration 1: Largest change in params was 0.384 in the m_probability of birth_year, level `Exact match`
# Iteration 2: Largest change in params was 0.332 in probability_two_random_records_match
# Iteration 3: Largest change in params was 0.0744 in probability_two_random_records_match
# Iteration 4: Largest change in params was 0.0158 in probability_two_random_records_match
# Iteration 5: Largest change in params was -0.00793 in the m_probability of gender, level `Exact match`
# Iteration 6: Largest change in params was 0.00176 in probability_two_random_records_match
# Iteration 7: Largest change in params was 0.00271 in the m_probability of birth_year, level `All other comparisons`
# Iteration 8: Largest change in params was -0.0044 in the m_probability of birth_year, level `Exact match`
# Iteration 9: Largest change in params was 0.00704 in the m_probability of birth_year, level `All other comparisons`
# Iteration 10: Largest change in params was 0.011 in the m_probability of birth_year, level `All other comparisons`
# Iteration 11: Largest change in params was 0.0167 in the m_probability of birth_year, level `All other comparisons`
# Iteration 12: Largest change in params was -0.024 in the m_probability of birth_year, level `Exact match`
# Iteration 13: Largest change in params was -0.0323 in the m_probability of birth_year, level `Exact match`
# Iteration 14: Largest change in params was -0.0396 in the m_probability of birth_year, level `Exact match`
# Iteration 15: Largest change in params was 0.0438 in the m_probability of birth_year, level `All other comparisons`
# Iteration 16: Largest change in params was -0.0434 in the m_probability of birth_year, level `Exact match`
# Iteration 17: Largest change in params was 0.0399 in probability_two_random_records_match
# Iteration 18: Largest change in params was 0.0367 in probability_two_random_records_match
# Iteration 19: Largest change in params was 0.0312 in probability_two_random_records_match
# Iteration 20: Largest change in params was 0.0249 in probability_two_random_records_match
# Iteration 21: Largest change in params was 0.019 in probability_two_random_records_match
# Iteration 22: Largest change in params was 0.014 in probability_two_random_records_match
# Iteration 23: Largest change in params was 0.0101 in probability_two_random_records_match
# Iteration 24: Largest change in params was 0.0071 in probability_two_random_records_match
# Iteration 25: Largest change in params was 0.00495 in probability_two_random_records_match
#
# EM converged after 25 iterations
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values
#
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# l.birth_year = r.birth_year and l.death_year = r.death_year and l.gender = r.gender
#
# Parameter estimates will be made for the following comparison(s):
#     - name
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - gender
#     - birth_year
#     - death_year
#
# Iteration 1: Largest change in params was 0.00019 in the m_probability of name, level `Levenshtein <= 1`
# Iteration 2: Largest change in params was -1.45e-05 in the m_probability of name, level `Exact match`
#
# EM converged after 2 iterations
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values
# ----- Estimating u probabilities using random sampling -----
#
# Estimated u probabilities using random sampling
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values

# %%
linker.match_weights_chart()
# Out:
# <div id="altair-viz-96fa7e27814c4a60b7d078d21acf884f"></div>
# <script type="text/javascript">
#   var VEGA_DEBUG = (typeof VEGA_DEBUG == "undefined") ? {} : VEGA_DEBUG;
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-96fa7e27814c4a60b7d078d21acf884f") {
#       outputDiv = document.getElementById("altair-viz-96fa7e27814c4a60b7d078d21acf884f");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.17.0?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function maybeLoadScript(lib, version) {
#       var key = `${lib.replace("-", "")}_version`;
#       return (VEGA_DEBUG[key] == version) ?
#         Promise.resolve(paths[lib]) :
#         new Promise(function(resolve, reject) {
#           var s = document.createElement('script');
#           document.getElementsByTagName("head")[0].appendChild(s);
#           s.async = true;
#           s.onload = () => {
#             VEGA_DEBUG[key] = version;
#             return resolve(paths[lib]);
#           };
#           s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#           s.src = paths[lib];
#         });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else {
#       maybeLoadScript("vega", "5")
#         .then(() => maybeLoadScript("vega-lite", "4.17.0"))
#         .then(() => maybeLoadScript("vega-embed", "6"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"width": 400, "height": 60}, "mark": {"tooltip": null}, "title": {"anchor": "middle"}, "header": {"title": null}}, "data": {"values": [{"comparison_name": "probability_two_random_records_match", "sql_condition": null, "label_for_charts": "", "m_probability": null, "u_probability": null, "m_probability_description": null, "u_probability_description": null, "has_tf_adjustments": false, "tf_adjustment_column": null, "tf_adjustment_weight": null, "is_null_level": false, "bayes_factor": 0.00010001000100010001, "log2_bayes_factor": -13.287568102831404, "comparison_vector_value": 0, "max_comparison_vector_value": 0, "bayes_factor_description": "The probability that two random records drawn at random match is 0.000 or one in  10,000.0 records.This is equivalent to a starting match weight of -13.288.", "probability_two_random_records_match": 0.0001, "comparison_sort_order": -1}, {"comparison_name": "name", "sql_condition": "\"name_l\" = \"name_r\"", "label_for_charts": "Exact match", "m_probability": 6.381666121081906e-05, "u_probability": 0.0006027929186494579, "m_probability_description": "Amongst matching record comparisons, 0.01% of records are in the exact match comparison level", "u_probability_description": "Amongst non-matching record comparisons, 0.06% of records are in the exact match comparison level", "has_tf_adjustments": false, "tf_adjustment_column": null, "tf_adjustment_weight": 1.0, "is_null_level": false, "bayes_factor": 0.10586829943821943, "log2_bayes_factor": -3.239657432750533, "comparison_vector_value": 2, "max_comparison_vector_value": 2, "bayes_factor_description": "If comparison level is `exact match` then comparison is  9.45 times less likely to be a match", "probability_two_random_records_match": 0.0001, "comparison_sort_order": 0}, {"comparison_name": "name", "sql_condition": "levenshtein(\"name_l\", \"name_r\") <= 1", "label_for_charts": "Levenshtein <= 1", "m_probability": 0.0015497755645761846, "u_probability": 5.9708276049730565e-05, "m_probability_description": "Amongst matching record comparisons, 0.15% of records are in the levenshtein <= 1 comparison level", "u_probability_description": "Amongst non-matching record comparisons, 0.01% of records are in the levenshtein <= 1 comparison level", "has_tf_adjustments": false, "tf_adjustment_column": null, "tf_adjustment_weight": 1.0, "is_null_level": false, "bayes_factor": 25.9557915101315, "log2_bayes_factor": 4.697984577621163, "comparison_vector_value": 1, "max_comparison_vector_value": 2, "bayes_factor_description": "If comparison level is `levenshtein <= 1` then comparison is 25.96 times more likely to be a match", "probability_two_random_records_match": 0.0001, "comparison_sort_order": 0}, {"comparison_name": "name", "sql_condition": "ELSE", "label_for_charts": "All other comparisons", "m_probability": 0.9983864077742131, "u_probability": 0.9993374988053008, "m_probability_description": "Amongst matching record comparisons, 99.84% of records are in the all other comparisons comparison level", "u_probability_description": "Amongst non-matching record comparisons, 99.93% of records are in the all other comparisons comparison level", "has_tf_adjustments": false, "tf_adjustment_column": null, "tf_adjustment_weight": 1.0, "is_null_level": false, "bayes_factor": 0.9990482784522499, "log2_bayes_factor": -0.001373697749858282, "comparison_vector_value": 0, "max_comparison_vector_value": 2, "bayes_factor_description": "If comparison level is `all other comparisons` then comparison is  1.00 times less likely to be a match", "probability_two_random_records_match": 0.0001, "comparison_sort_order": 0}, {"comparison_name": "gender", "sql_condition": "\"gender_l\" = \"gender_r\"", "label_for_charts": "Exact match", "m_probability": 0.9950620828368993, "u_probability": 0.6114555686597178, "m_probability_description": "Amongst matching record comparisons, 99.51% of records are in the exact match comparison level", "u_probability_description" ...

# %%
linker.m_u_parameters_chart()
# Out:
# <div id="altair-viz-469f2a9df0e74c21a32123e035cf0bb8"></div>
# <script type="text/javascript">
#   var VEGA_DEBUG = (typeof VEGA_DEBUG == "undefined") ? {} : VEGA_DEBUG;
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-469f2a9df0e74c21a32123e035cf0bb8") {
#       outputDiv = document.getElementById("altair-viz-469f2a9df0e74c21a32123e035cf0bb8");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.17.0?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function maybeLoadScript(lib, version) {
#       var key = `${lib.replace("-", "")}_version`;
#       return (VEGA_DEBUG[key] == version) ?
#         Promise.resolve(paths[lib]) :
#         new Promise(function(resolve, reject) {
#           var s = document.createElement('script');
#           document.getElementsByTagName("head")[0].appendChild(s);
#           s.async = true;
#           s.onload = () => {
#             VEGA_DEBUG[key] = version;
#             return resolve(paths[lib]);
#           };
#           s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#           s.src = paths[lib];
#         });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else {
#       maybeLoadScript("vega", "5")
#         .then(() => maybeLoadScript("vega-lite", "4.17.0"))
#         .then(() => maybeLoadScript("vega-embed", "6"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"width": 400, "height": 300}, "title": {"anchor": "middle", "offset": 10}, "header": {"title": null}}, "hconcat": [{"mark": "bar", "title": {"text": "Amongst matching record comparisons:", "fontWeight": "bold", "fontSize": 12}, "encoding": {"row": {"type": "nominal", "field": "comparison_name", "sort": {"field": "comparison_sort_order"}, "header": {"labelAngle": 0, "labelAnchor": "middle", "labelAlign": "left"}}, "x": {"type": "quantitative", "field": "m_probability", "axis": {"title": "Proportion of record comparisons"}}, "y": {"type": "nominal", "axis": {"title": null}, "field": "label_for_charts", "sort": {"field": "comparison_vector_value", "order": "descending"}}, "tooltip": [{"type": "nominal", "field": "m_probability_description", "title": "m probability description"}, {"type": "nominal", "field": "comparison_name", "title": "Comparison column name"}, {"type": "ordinal", "field": "label_for_charts", "title": "Label"}, {"type": "nominal", "field": "sql_condition", "title": "SQL condition"}, {"type": "quantitative", "field": "m_probability", "format": ".4p", "title": "m probability"}, {"type": "quantitative", "field": "u_probability", "format": ".4p", "title": "u probability"}, {"type": "quantitative", "field": "bayes_factor", "title": "Bayes factor = m/u", "format": ",.4f"}, {"type": "quantitative", "field": "log2_bayes_factor", "title": "Match weight = log2(m/u)", "format": ",.4f"}], "color": {"value": "green"}}, "resolve": {"scale": {"y": "independent"}}, "transform": [{"filter": "(datum.bayes_factor != 'no-op filter due to vega lite issue 4680')"}], "width": 150, "height": {"step": 12}}, {"mark": "bar", "title": {"text": "Amongst non-matching record comparisons:", "fontWeight": "bold", "fontSize": 12}, "encoding": {"row": {"type": "nominal", "field": "comparison_name", "sort": {"field": "comparison_sort_order"}, "header": {"labels": false}}, "x": {"type": "quantitative", "field": "u_probability", "axis": {"title": "Proportion of record comparisons"}}, "y": {"type": "nominal", "axis": {"title": null}, "field": "label_for_charts", "sort": {"field": "comparison_vector_value", "order": "descending"}}, "tooltip": [{"type": "nominal", "field": "u_probability_description", "title": "u probability description"}, {"type": "nominal", "field": "comparison_name", "title": "Comparison column name"}, {"type": "ordinal", "field": "label_for_charts", "title": "Label"}, {"type": "nominal", "field": "sql_condition", "title": "SQL condition"}, {"type": "quantitative", "field": "m_probability", "format": ".4p", "title": "m probability"}, {"type": "quantitative", "field": "u_probability", "format": ".4p", "title": "u probability"}, {"type": "quantitative", "field": "bayes_factor", "title": "Bayes factor = m/u", "format": ",.4f"}, {"type": "quantitative", "field": "log2_bayes_factor", "title": "Match weight = log2(m/u)", "format": ",.4f"}], "color": {"value": "red"}}, "resolve": {"scale": {"y": "independent"}}, "transform": [{"filter": "(datum.bayes_factor != 'no-op filter2 due to vega lite issue 4680')"}], "width": 150, "height": {"step": 12}}], "data": {"values": [{"comparison_name": "name", "sql_condition": "\"name_l\" = \"name_r\"", "label_for_charts": "Exact match", "m_probability": 6.381666121081906e-05, "u_probability": 0.0006027929186494579, "m_probability_description": "Amongst matching record comparisons, 0.01% of records are in the exact match comparison level", "u_probability_description": "Amongst non-matching record comparisons, 0.06% of records are in the exact match comparison level", "has_tf_adjustments": false, "tf_adjustment_column": null, "tf_adjustment_weight": 1.0, "is_null_level": false, "bayes_factor": 0.10586829943821943, "log2_bayes_factor": -3.239657432750533, "comparison_vector_value": 2, "max_comparison_vector_value": 2, "bayes_factor_description": "If comparison level is `exact match` then comparison is  9.45 times less likely to be a match", "probability_two_random_records_match": 0. ...

# %%
linker.predict().as_pandas_dataframe().sort_values('match_probability', ascending=False).head(50)#[0:1000].sample(10)
# Out:
#         match_weight  match_probability unique_id_l unique_id_r  \
# 245947      7.717797           0.995272    bhp36032    bhp36034
# 244788      7.717797           0.995272    bhp36203    bhp36235
# 518475      7.717797           0.995272    bhp56048    bhp56049
# 289497      7.717797           0.995272    bhp39931    bhp39932
# 289501      7.717797           0.995272    bhp39937    bhp39938
# 344196      7.717797           0.995272    bhp51564    bhp51565
# 344195      7.717797           0.995272    bhp51559    bhp51560
# 518487      7.717797           0.995272    bhp56087    bhp56088
# 344194      7.717797           0.995272    bhp51555    bhp51556
# 344186      7.717797           0.995272    bhp51494    bhp51496
# 518494      7.717797           0.995272    bhp56123    bhp56124
# 289511      7.717797           0.995272    bhp39950    bhp39951
# 289512      7.717797           0.995272    bhp39952    bhp39953
# 289514      7.717797           0.995272    bhp39957    bhp39958
# 344180      7.717797           0.995272    bhp51449    bhp51450
# 244944      7.717797           0.995272    bhp36557    bhp36558
# 289488                     jacob stöcker                     jakob stöcker
# 344209                     gabriel douet                    gabriel douhet
# 518470                  ludovico maracci                 ludovico marracci
# 239452                     richard zouch                    richard zouche
# 244795                    enoch heylandt                    enoch heilandt
# 244796                     enoch heiland                    enoch heilandt
# 298175                   gabriel tüntzel                    gabriel tünzel
# 244806                 polycarp heylandt                 polycarp heilandt
# 244807                  polycarp heiland                 polycarp heilandt
# 244810                     johann gorman                    johann gormann
# 344268                  lambert rouvière                   lambert rovière
# 244812                  michael heylandt                  michael heilandt
# 244813                   michael heiland                  michael heilandt
# 244817       anna elisabeth grosshenning        anna elisabeth grosshennig
# 344266                    lambert roland                   lambert rolland
# 501712                       paul lauras                      paul laurans
# 298192                      johann ockel                       johann okel
# 289478                      melchior leh                     melchior lehe
# 298195                      michael vogt                     michael voigt
# 289446        sebastian gottfried starck       sebastian gottfried starcke
# 244846          johanna gertraudt steger           johanna gertraud steger
#
#         gamma_name gender_l gender_r  gamma_gender  birth_year_l  \
# 245947           1     Male     Male             1        1649.0
# 244788           1     Male     Male             1        1651.0
# 518475           1     Male     Male             1        1635.0
# 289497           1   Female   Female             1        1631.0
# 289501           1   Female   Female             1        1582.0
# 344196           1     Male     Male             1        1669.0
# 344195           1     Male     Male             1        1501.0
# 518487           1     Male     Male             1        1624.0
# 344194           1   Female   Female             1        1560.0
# 344186           1     Male     Male             1        1260.0
# 518494           1     Male     Male             1        1572.0
# 289511           1     Male     Male             1        1597.0
# 289512           1     Male     Male             1        1590.0
# 289514           1     Male     Male             1        1611.0
# 344180           1     Male     Male             1        1605.0
# 244944           1     Male     Male             1        1617.0
# 344171           1     Male     Male             1        1635.0
# 141237           1     Male     Male             1        1666.0
# 298280           1     Male     Male             1        1877.0
# 344166           1     Male     Male             1        1624.0
# 133040           1     Male     Male             1        1439.0
# 131127           1     Male     Male             1        1587.0
# 133016           1     Male     Male             1        1584.0
# 518543           1     Male     Male             1        1620.0
# 133004           1     Male     Male             1        1820.0
# 518554           1     Male     Male             1        1635.0
# 319304           1     Male     Male             1        1582.0
# 518573           1     Male     Male             1        1616.0
# 290029           1   Female   Female             1        1570.0
# 289488           1     Male     Male             1        1572.0
# 344209           1     Male     Male             1        1688.0
# 518470           1     Male     Male             1        1612.0
# 239452           1     Male     Male             1        1590.0
# 244795           1     Male     Male             1        1648.0
# 244796           1     Male     Male             1        1648.0
# 298175           1     Male     Male             1        1576.0
# 244806           1     Male     Male             1        1651.0
# 244807           1     Male     Male             1        1651.0
# 244810           1     Male     Male             1        1575.0
# 344268           1     Male     Male             1        1679.0
# 244812           1     Male     Male             1        1624.0
# 244813           1     Male     Male             1        1624.0
# 244817           1   Female   Female             1        1623.0
# 344266           1     Male     Male             1        1678.0
# 501712           1     Male     Male             1        1825.0
# 298192           1     Male     Male             1        1610.0
# 289478           1     Male     Male             1        1568.0
# 298195           1     Male     Male             1        1640.0
# 289446           1     Male     Male             1        1612.0
# 244846           1   Female   Female             1        1668.0
#
#         birth_year_r  gamma_birth_year  death_year_l  death_year_r  \
# 245947        1649.0                 1        1663.0        1663.0
# 244788        1651.0                 1        1702.0        1702.0
# 518475        1635.0                 1        1683.0        1683.0
